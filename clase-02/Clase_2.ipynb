# %% [markdown]
# # Mis primeros pasos
#
# * Lo que esta en comilla es un string
# * Si un string empieza con f le puedo {} y llamar la variable

# %%
print("Dame tu nombre y te saludo")
nombre = input("Decime tu nombre")

print(f"Bienvenido {nombre}")
# Out:
# Dame tu nombre y te saludo
# Decime tu nombreFacu
# Bienvenido Facu

# %% [markdown]
# Hecho con Claude
# * El import hace mencion a las librerias de python a utilizar

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y, marker='o')
plt.title("Ejemplo de gráfico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)
plt.show()
